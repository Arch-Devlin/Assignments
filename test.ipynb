# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport

# %%
earthquakes = pd.read_csv("all_month.csv")
earthquakes
# Out:
#                           time   latitude   longitude       depth   mag  \
# 0     2021-11-25T02:22:39.990Z  33.665833 -116.775667   14.430000  0.98
# 1     2021-11-25T02:18:47.640Z  38.564999 -119.455498    2.500000  2.11
# 2     2021-11-25T02:16:05.228Z  36.368938  -97.340614    2.847088  2.34
# 3     2021-11-25T02:04:54.180Z  19.188499 -155.487167   30.600000  1.72
# 4     2021-11-25T01:57:27.020Z  33.490500 -116.785167    3.350000  1.38
# ...                        ...        ...         ...         ...   ...
# 9354  2021-10-26T03:00:34.922Z  62.869200 -151.236000  108.000000  1.40
# 9355  2021-10-26T02:56:37.950Z  39.431000 -110.326833   -1.220000  1.39
# 9356  2021-10-26T02:52:34.940Z  47.563167 -114.135167    5.210000 -0.13
# 9357  2021-10-26T02:46:44.410Z  53.858833 -166.763000    7.030000  0.00
# 9358  2021-10-26T02:39:32.600Z  38.423833 -122.626833    5.210000  1.97
#
#      magType   nst         gap      dmin       rms  ...  \
# ...

# %%
# %matplotlib inline
fig, ax = plt.subplots()
earthquakes.boxplot(column=['mag'], ax=ax)
# Out:
# <AxesSubplot:>

# %%
fig, ax = plt.subplots()
plt.scatter(earthquakes["latitude"],earthquakes["mag"], color = "red")
ax.set_ylabel("Magnitude")
ax.set_xlabel("Latitude")
# Out:
# Text(0.5, 0, 'Latitude')

# %%
fig, ax = plt.subplots()
plt.scatter(earthquakes["mag"], earthquakes["latitude"], color = "green")
ax.set_xlabel("Magnitude")
ax.set_ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
fig, ax = plt.subplots()
plt.scatter(earthquakes["longitude"],earthquakes["mag"], color = "red")
ax.set_ylabel("Magnitude")
ax.set_xlabel("Longitude")
# Out:
# Text(0.5, 0, 'Longitude')

# %%
fig, ax = plt.subplots()
plt.scatter(earthquakes["depth"],earthquakes["mag"])
ax.set_ylabel("Magnitude")
ax.set_xlabel("Depth")
# Out:
# Text(0.5, 0, 'Depth')

# %%
fig, ax = plt.subplots()
plt.hist(earthquakes["depth"])
ax.set_ylabel("Number of Earthquakes")
ax.set_xlabel("Depth")
# Out:
# Text(0.5, 0, 'Depth')

# %%
fig, ax = plt.subplots()
plt.hist(earthquakes["depth"], bins = 100)
ax.set_ylabel("Number of Earthquakes")
ax.set_xlabel("Depth")
# Out:
# Text(0.5, 0, 'Depth')

# %%
fig, ax = plt.subplots()
plt.scatter(earthquakes["depth"], earthquakes["mag"])
ax.set_ylabel("Magnitude")
ax.set_xlabel("Depth")
# Out:
# Text(0.5, 0, 'Depth')

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(earthquakes["longitude"],earthquakes["latitude"])
ax.set_ylabel("latitude")
ax.set_xlabel("longitude")
ax.set_title("Earthquake Location")
# Out:
# Text(0.5, 1.0, 'Earthquake Location')

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(earthquakes["longitude"],earthquakes["latitude"])
ax.set_ylabel("latitude")
ax.set_xlabel("longitude")
ax.set_title("Earthquake Location")
# Out:
# Text(0.5, 1.0, 'Earthquake Location')

# %%
Type = pd.DataFrame(earthquakes["magType"].value_counts())
Type.reset_index(inplace=True)

Type
# Out:
#    index  magType
# 0     ml     5402
# 1     md     3041
# 2     mb      792
# 3    mww       71
# 4    mwr       22
# 5  mb_lg       19
# 6     mh        4
# 7     mw        4
# 8    mwb        2
# 9    mun        1

# %%
earthquakes
# Out:
#                           time   latitude   longitude       depth   mag  \
# 0     2021-11-25T02:22:39.990Z  33.665833 -116.775667   14.430000  0.98
# 1     2021-11-25T02:18:47.640Z  38.564999 -119.455498    2.500000  2.11
# 2     2021-11-25T02:16:05.228Z  36.368938  -97.340614    2.847088  2.34
# 3     2021-11-25T02:04:54.180Z  19.188499 -155.487167   30.600000  1.72
# 4     2021-11-25T01:57:27.020Z  33.490500 -116.785167    3.350000  1.38
# ...                        ...        ...         ...         ...   ...
# 9354  2021-10-26T03:00:34.922Z  62.869200 -151.236000  108.000000  1.40
# 9355  2021-10-26T02:56:37.950Z  39.431000 -110.326833   -1.220000  1.39
# 9356  2021-10-26T02:52:34.940Z  47.563167 -114.135167    5.210000 -0.13
# 9357  2021-10-26T02:46:44.410Z  53.858833 -166.763000    7.030000  0.00
# 9358  2021-10-26T02:39:32.600Z  38.423833 -122.626833    5.210000  1.97
#
#      magType   nst         gap      dmin       rms  ...  \
# ...

# %%
esor = earthquakes.sort_values("mag", axis=0, ascending = False)
esor = esor.head(100)
esor
# Out:
#                           time  latitude  longitude   depth  mag magType  nst  \
# 4304  2021-11-10T15:45:13.651Z   23.5934   126.4478   12.00  6.6     mww  NaN
# 3126  2021-11-14T12:08:38.970Z   27.7361    56.0766   10.00  6.3      mb  NaN
# 4707  2021-11-09T06:25:17.066Z   11.2315   -86.5185   35.00  6.2     mww  NaN
# 1824  2021-11-18T14:08:05.061Z   -5.3134   153.7363   34.90  6.2     mww  NaN
# 7150  2021-11-01T17:04:16.558Z    0.2088    96.7094    8.00  6.0     mww  NaN
# ...                        ...       ...        ...     ...  ...     ...  ...
# 2213  2021-11-17T05:54:29.979Z   33.5310   121.1581   10.00  5.0     mww  NaN
# 6514  2021-11-03T12:45:41.680Z  -18.4933   168.9294  227.04  5.0     mww  NaN
# 8326  2021-10-29T06:38:20.317Z  -59.1418   -25.7541   48.06  5.0      mb  NaN
# 1781  2021-11-18T17:54:06.365Z   26.5280   129.9969   10.00  5.0      mb  NaN
# 4912  2021-11-08T17:23:01.854Z  -56.6547   -25.0301   10.00  5.0      mb  NaN
#
# ...

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(esor["longitude"], esor["latitude"])
ax.set_ylabel("latitude")
ax.set_xlabel("longitude")
ax.set_title("Earthquake Location")
# Out:
# Text(0.5, 1.0, 'Earthquake Location')

# %%
fig, ax = plt.subplots()
plt.scatter(esor["depth"], esor["mag"])
ax.set_ylabel("Magnitude")
ax.set_xlabel("Depth")
# Out:
# Text(0.5, 0, 'Depth')

# %%
esor2 = earthquakes.sort_values("mag", axis=0, ascending = False)
esor2 = esor2.head(1000)
esor2
# Out:
#                           time  latitude  longitude   depth  mag magType  \
# 4304  2021-11-10T15:45:13.651Z   23.5934   126.4478   12.00  6.6     mww
# 3126  2021-11-14T12:08:38.970Z   27.7361    56.0766   10.00  6.3      mb
# 4707  2021-11-09T06:25:17.066Z   11.2315   -86.5185   35.00  6.2     mww
# 1824  2021-11-18T14:08:05.061Z   -5.3134   153.7363   34.90  6.2     mww
# 7150  2021-11-01T17:04:16.558Z    0.2088    96.7094    8.00  6.0     mww
# ...                        ...       ...        ...     ...  ...     ...
# 2960  2021-11-15T01:19:57.746Z   50.9757  -179.8044   13.06  3.3      ml
# 58    2021-11-24T20:13:22.552Z   56.1415  -149.2472   10.00  3.3      ml
# 7214  2021-11-01T12:59:28.122Z   43.9135  -129.9130   10.00  3.3      ml
# 4712  2021-11-09T05:57:44.679Z   56.1554  -161.3658  199.07  3.3      ml
# 6008  2021-11-05T09:26:07.670Z   18.1890   -67.6670    4.00  3.3      md
#
#        nst    gap    dmin   rms  ...                   updated  \
# ...

# %%
fig, ax = plt.subplots()
plt.scatter(esor2["depth"], esor2["mag"])
ax.set_ylabel("Magnitude")
ax.set_xlabel("Depth")
# Out:
# Text(0.5, 0, 'Depth')

# %%
esor3 = earthquakes.sort_values("latitude", axis=0, ascending = True)
esor3 = esor3.head(606)
esor3
# Out:
#                           time  latitude  longitude   depth  mag magType  nst  \
# 6812  2021-11-02T17:00:46.473Z  -62.6243   155.4631   10.00  5.4     mww  NaN
# 1295  2021-11-20T08:21:06.986Z  -61.0503   -37.5134   10.00  4.9      mb  NaN
# 6592  2021-11-03T07:28:29.330Z  -60.3961   -24.2685   35.00  4.9      mb  NaN
# 5679  2021-11-06T09:56:22.566Z  -60.1682   -24.6229   10.00  4.7      mb  NaN
# 3131  2021-11-14T11:59:35.467Z  -60.1048   -24.9053   10.00  5.0      mb  NaN
# ...                        ...       ...        ...     ...  ...     ...  ...
# 3473  2021-11-13T10:21:34.370Z   16.4964   -95.1613   31.40  4.3      mb  NaN
# 8334  2021-10-29T05:54:06.163Z   16.8931   -95.0869   98.28  4.4      mb  NaN
# 682   2021-11-22T15:12:05.776Z   17.3598   145.7842  205.27  4.8      mb  NaN
# 8160  2021-10-29T18:33:25.255Z   17.6187  -101.0423   55.61  4.3      mb  NaN
# 1330  2021-11-20T05:54:53.661Z   17.6261   -94.1904  152.26  4.2      mb  NaN
#
# ...

# %%
fig, ax = plt.subplots()
plt.scatter(esor3["mag"], esor3["latitude"], color = "green")
ax.set_xlabel("Magnitude")
ax.set_ylabel("Latitude")
# Out:
# Text(0, 0.5, 'Latitude')

# %%
esor3 = esor3.sort_values("longitude", axis=0, ascending = False)
esor3 = esor3.head(606)
esor3
# Out:
#                           time  latitude  longitude   depth  mag magType  nst  \
# 5542  2021-11-06T20:32:52.918Z  -24.3381   179.9410  514.13  4.7      mb  NaN
# 9148  2021-10-26T18:01:47.091Z  -33.8173   179.9239   74.92  4.3      mb  NaN
# 4641  2021-11-09T11:03:52.577Z  -24.1297   179.9159  518.86  4.1      mb  NaN
# 6458  2021-11-03T17:47:26.613Z  -24.8476   179.8812  504.12  4.3      mb  NaN
# 5321  2021-11-07T15:23:08.999Z  -29.7756   179.7612  454.58  4.1      mb  NaN
# ...                        ...       ...        ...     ...  ...     ...  ...
# 1437  2021-11-19T20:45:30.998Z  -16.5847  -179.8885  543.56  4.3      mb  NaN
# 483   2021-11-23T08:17:45.169Z  -24.0746  -179.8989  527.05  4.5      mb  NaN
# 8940  2021-10-27T07:32:06.599Z  -24.6410  -179.9146  498.90  4.5      mb  NaN
# 5181  2021-11-08T03:08:59.579Z  -34.4068  -179.9433   61.26  4.2      mb  NaN
# 5998  2021-11-05T10:05:51.571Z  -23.6225  -179.9673  553.35  4.3      mb  NaN
#
# ...

# %%
fig, ax = plt.subplots()
plt.scatter(esor3["longitude"],esor3["mag"], color = "red")
ax.set_ylabel("Magnitude")
ax.set_xlabel("Longitude")
# Out:
# Text(0.5, 0, 'Longitude')

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(esor3["longitude"],esor3["latitude"])
ax.set_ylabel("latitude")
ax.set_xlabel("longitude")
ax.set_title("Earthquake Location")
# Out:
# Text(0.5, 1.0, 'Earthquake Location')

# %%
fig, ax = plt.subplots()
plt.scatter(esor3["depth"],esor3["mag"])
ax.set_ylabel("Magnitude")
ax.set_xlabel("Depth")
ax.set_title("Efect of Depth on Magnitude in Area of Least Variability in Magnitude")
# Out:
# Text(0.5, 1.0, 'Efect of Depth on Magnitude in Area of Least Variability in Magnitude')

# %%
fig, ax = plt.subplots()
plt.hist(esor3["depth"], bins = 30)
ax.set_ylabel("Number of Earthquakes")
ax.set_xlabel("Depth")
ax.set_title("Number of Earthquakes at Varying Depths in Area of Least Variability in Magnitude")
# Out:
# Text(0.5, 1.0, 'Number of Earthquakes at Varying Depths in Area of Least Variability in Magnitude')

# %%
esor4 = earthquakes.sort_values("latitude", axis=0, ascending = False)
esor4 = esor4.head(8753)
esor4 = earthquakes.sort_values("longitude", axis=0, ascending = True)
esor4 = esor4.head(8740)
esor4
# Out:
#                           time  latitude  longitude   depth   mag magType  \
# 5998  2021-11-05T10:05:51.571Z  -23.6225  -179.9673  553.35  4.30      mb
# 5181  2021-11-08T03:08:59.579Z  -34.4068  -179.9433   61.26  4.20      mb
# 4997  2021-11-08T12:39:18.189Z   51.3648  -179.9418   13.80  2.20      ml
# 8940  2021-10-27T07:32:06.599Z  -24.6410  -179.9146  498.90  4.50      mb
# 483   2021-11-23T08:17:45.169Z  -24.0746  -179.8989  527.05  4.50      mb
# ...                        ...       ...        ...     ...   ...     ...
# 8628  2021-10-28T08:08:39.900Z   18.2450   -64.2801    9.00  3.43      md
# 8633  2021-10-28T07:55:57.850Z   18.5413   -64.2331   50.00  3.56      md
# 7101  2021-11-01T20:26:24.040Z   19.5855   -63.5216   43.00  4.05      md
# 2021  2021-11-17T21:38:53.587Z  -26.3334   -63.3403  569.91  5.50     mww
# 7081  2021-11-01T22:08:17.732Z   18.4295   -62.3407   32.38  5.00     mww
#
#        nst    gap    dmin   rms  ...                   updated  \
# ...

# %%
# %matplotlib inline
fig, ax = plt.subplots()
plt.scatter(esor4["longitude"],esor4["latitude"])
ax.set_ylabel("latitude")
ax.set_xlabel("longitude")
ax.set_title("Earthquake Location")
# Out:
# Text(0.5, 1.0, 'Earthquake Location')

# %%
fig, ax = plt.subplots()
plt.hist(esor4["depth"], bins = 30)
ax.set_ylabel("Number of Earthquakes")
ax.set_xlabel("Depth")
ax.set_title("Number of Earthquakes at Varying Depths in Area of Most Variability in Magnitude")
# Out:
# Text(0.5, 1.0, 'Number of Earthquakes at Varying Depths in Area of Most Variability in Magnitude')

# %%
fig, ax = plt.subplots()
plt.scatter(esor4["depth"],esor4["mag"])
ax.set_ylabel("Magnitude")
ax.set_xlabel("Depth")
ax.set_title("Efect of Depth on Magnitude in Area of Most Variability in Magnitude")
# Out:
# Text(0.5, 1.0, 'Efect of Depth on Magnitude in Area of Most Variability in Magnitude')
